# %%
from report_gui import report_gui, report_range

# %%
report_gui()

# %%
# %matplotlib inline
hutch_patches = [
    ("2025-09-02 06:00", 60*12, "XCS"),
    ("2025-09-03 06:00", 60*12, "XCS"),
    ("2025-09-04 06:00", 60*12, "XCS"),
    ("2025-09-05 06:00", 60*12, "XCS"),
    ("2025-09-06 06:00", 60*12, "XCS"),
    ("2025-09-06 18:00", 60*12, "XCS"),
    ("2025-09-02 18:00", 60*12, "MEC"),
    ("2025-09-03 18:00", 60*12, "MEC"),
    ("2025-09-04 18:00", 60*12, "MEC"),
    ("2025-09-05 18:00", 60*12, "MEC"),
    ("2025-09-07 18:00", 60*12, "MEC"),
    ("2025-09-08 18:00", 60*12, "MEC"),
    ("2025-09-08 06:00", 60*12, "CXI"),
    ("2025-09-09 06:00", 60*12, "CXI"),
    ("2025-09-09 18:00", 60*6, "XCS"),
    ("2025-09-07 06:00", 60*12, "TXI"),
  
]

comment_patches = [
    ("2025-09-03 02:00", 60*8, "BSY lost", "MEC"),
]

report_range("2025-09-09 15:59", "8d", hutch_patches=hutch_patches)#, comment_patches=comment_patches)

# %%
# %matplotlib inline
hutch_patches = [
    ("2025-09-09 00:00", 60*12, "MEC"),
    ("2025-09-09 06:00", 60*12, "CXI"),
    ("2025-09-11 18:00", 60*12, "CXI"),
    ("2025-09-12 18:00", 60*12, "CXI"),
    ("2025-09-13 18:00", 60*12, "CXI"),
    ("2025-09-14 18:00", 60*12, "CXI"),
    ("2025-09-11 06:00", 60*12, "MFX"),
    ("2025-09-12 06:00", 60*12, "MFX"),
    ("2025-09-13 06:00", 60*12, "MFX"),
    ("2025-09-14 06:00", 60*12, "TMO"),
    ("2025-09-15 06:00", 60*12, "TMO"),
    ("2025-09-15 06:00", 60*12, "TMO"),
    ("2025-09-15 06:00", 60*12, "TMO"),
  
]

# comment_patches = [
#     ("2025-09-09 18:00", 60*12, "MD", "XCS"),
# ]

report_range("2025-09-15 23:59", "3d", hutch_patches=hutch_patches)#, comment_patches=comment_patches)
