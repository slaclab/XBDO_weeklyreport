# %%
from report_gui import report_gui

# %%
report_gui()
# Out:
# VBox(children=(HBox(children=(DatePicker(value=datetime.date(2025, 9, 17), description='End date', step=1), Te…

# %%
report_gui()
# Out:
# VBox(children=(HBox(children=(DatePicker(value=datetime.date(2025, 9, 17), description='End date', step=1), Te…

# %% [markdown]
# report_gui()

# %%
from report_gui import report_range

# %%
# %matplotlib inline
hutch_patches = [
    ("2025-09-02 06:00", 60*12, "XCS"),
    ("2025-09-03 06:00", 60*12, "XCS"),
    ("2025-09-04 06:00", 60*12, "XCS"),
    ("2025-09-05 06:00", 60*12, "XCS"),
    ("2025-09-06 06:00", 60*12, "XCS"),
    ("2025-09-06 18:00", 60*12, "XCS"),
    ("2025-09-02 18:00", 60*12, "MEC"),
    ("2025-09-03 18:00", 60*12, "MEC"),
    ("2025-09-04 18:00", 60*12, "MEC"),
    ("2025-09-05 18:00", 60*12, "MEC"),
    ("2025-09-07 18:00", 60*12, "MEC"),
    ("2025-09-08 18:00", 60*12, "MEC"),
    ("2025-09-08 06:00", 60*12, "CXI"),
    ("2025-09-09 06:00", 60*12, "CXI"),
    ("2025-09-09 18:00", 60*6, "XCS"),

    ("2025-09-07 06:00", 60*12, "TXI"),
  
]

comment_patches = [
    ("2025-09-03 02:00", 60*8, "BSY lost", "MEC"),
]

report_range("2025-09-09 23:59", "8d", hutch_patches=hutch_patches, comment_patches=comment_patches)

# %%
from report_gui_test import report_gui
# importlib.reload(report_gui)

# %%
import importlib

# %%
report_gui()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 report_gui()
#
# File ~/XBDO_weeklyreport/report_gui_test.py:108, in report_gui()
#     106 def report_gui():
#     107     # --- End date/time ---
# --> 108     end_date_picker = DatePicker(value=datetime.today().date(), description="End date")
#     109     end_time_text = Text(value="06:00:00", description="Time")
#     110     period = Dropdown(options=["1d","7d","8d","9d","14d"], value="7d", description="Period")
#
# NameError: name 'DatePicker' is not defined
