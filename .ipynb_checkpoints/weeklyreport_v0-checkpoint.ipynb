# %%
from report_gui import report_gui

# %%
report_gui()

# %%
from report_gui import report_range

# %%
# %matplotlib inline
hutch_patches = [
    ("2025-07-10 06:00", 60*24, "XCS"),
    ("2025-07-11 06:00", 60*12, "XCS"),
    ("2025-07-12 06:00", 60*12, "XCS"),
    ("2025-07-13 06:00", 60*12, "XCS"),    
    ("2025-07-09 09:00", 60*12, "CXI"),
    ("2025-07-10 18:00", 60*12, "CXI"),
    ("2025-07-11 18:00", 60*12, "CXI"),
    ("2025-07-12 18:00", 60*12, "CXI"),
    ("2025-07-13 18:00", 60*12, "MFX"),
    ("2025-07-14 18:00", 60*12, "MEC"),  
]

comment_patches = [
    ("2025-07-10 09:15", 120, "Start experiment issue", "XCS"),
    ("2025-07-09 14:00", 250, "Shutter delay", "CXI"),
    ("2025-07-12 14:00", 10, "Shutter delay", "CXI"),
    ("2025-07-13 14:00", 30, "Shutter delay", "CXI"),
    ("2025-07-10 14:00", 60, "Shutter delay", "CXI"),
]

report_range("2025-07-15 06:00", "7d", hutch_patches=hutch_patches, comment_patches=comment_patches)
